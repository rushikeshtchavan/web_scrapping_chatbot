# %%
import nltk
import numpy as np
import random
import string

import bs4 as bs
import urllib.request
import re

# %%
# !pip install beautifulsoup4

# %%
# pass the questions based on web page
link = urllib.request.urlopen('https://en.wikipedia.org/wiki/Data_science')  #acces the data from webpage

# %%
link = link.read() #read the webpage

# %%
data =bs.BeautifulSoup(link,'lxml') #data is extracted and stored in lxml format

# %%
data  #read the data
# Out:
# <!DOCTYPE html>
# <html class="client-nojs vector-feature-language-in-header-enabled vector-feature-language-in-main-page-header-disabled vector-feature-sticky-header-disabled vector-feature-page-tools-pinned-disabled vector-feature-toc-pinned-clientpref-1 vector-feature-main-menu-pinned-disabled vector-feature-limited-width-clientpref-1 vector-feature-limited-width-content-enabled vector-feature-custom-font-size-clientpref-1 vector-feature-appearance-pinned-clientpref-1 vector-feature-night-mode-enabled skin-theme-clientpref-day vector-toc-available" dir="ltr" lang="en">
# <head>
# <meta charset="utf-8"/>
# <title>Data science - Wikipedia</title>
# ...

# %%
#check para
data_paragraphs =data.find_all('p')

# %%
# get the text and covert it into lower format
data_text = ''
for para in data_paragraphs:
    data_text +=para.text

# %%
data_text
# Out:
# '\nData science is an interdisciplinary academic field[1] that uses statistics, scientific computing, scientific methods, processing, scientific visualization, algorithms and systems to extract or extrapolate knowledge and insights from potentially noisy, structured, or unstructured data.[2]\nData science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).[3] Data science is multifaceted and can be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession.[4]\nData science is "a concept to unify statistics, data analysis, informatics, and their related methods" to "understand and analyze actual phenomena" with data.[5] It uses techniques and theories drawn from many fields within the context of mathematics, statistics, computer science, information science, and domain knowledge.[6] However, data science is different from computer science and information
# ...

# %%
data_text =data_text.lower() #convert all characters in the string data_text to lowercase

# %%
data_text
# Out:
# '\ndata science is an interdisciplinary academic field[1] that uses statistics, scientific computing, scientific methods, processing, scientific visualization, algorithms and systems to extract or extrapolate knowledge and insights from potentially noisy, structured, or unstructured data.[2]\ndata science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).[3] data science is multifaceted and can be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession.[4]\ndata science is "a concept to unify statistics, data analysis, informatics, and their related methods" to "understand and analyze actual phenomena" with data.[5] it uses techniques and theories drawn from many fields within the context of mathematics, statistics, computer science, information science, and domain knowledge.[6] however, data science is different from computer science and information
# ...

# %%
# remove [] num 
data_text =re.sub(r'\[[0-9]*\]',' ',data_text)
data_text =re.sub(r'\s+',' ',data_text)        #remove \

# %%
data_text
# Out:
# ' data science is an interdisciplinary academic field that uses statistics, scientific computing, scientific methods, processing, scientific visualization, algorithms and systems to extract or extrapolate knowledge and insights from potentially noisy, structured, or unstructured data. data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine). data science is multifaceted and can be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession. data science is "a concept to unify statistics, data analysis, informatics, and their related methods" to "understand and analyze actual phenomena" with data. it uses techniques and theories drawn from many fields within the context of mathematics, statistics, computer science, information science, and domain knowledge. however, data science is different from computer science and information science. turing awar
# ...

# %%
#perform tokenization

sen =nltk.sent_tokenize(data_text)
words =nltk.word_tokenize(data_text)
# Out:
# ---------------------------------------------------------------------------
# LookupError                               Traceback (most recent call last)
# <ipython-input-14-9ebd9a12c2fc> in <cell line: 3>()
#       1 #perform tokenization
#       2
# ----> 3 sen =nltk.sent_tokenize(data_text)
#       4 words =nltk.word_tokenize(data_text)
#
# /usr/local/lib/python3.10/dist-packages/nltk/tokenize/__init__.py in sent_tokenize(text, language)
#     117     :param language: the model name in the Punkt corpus
#     118     """
# --> 119     tokenizer = _get_punkt_tokenizer(language)
#     120     return tokenizer.tokenize(text)
#     121
#
# /usr/local/lib/python3.10/dist-packages/nltk/tokenize/__init__.py in _get_punkt_tokenizer(language)
#     103     :type language: str
#     104     """
# --> 105     return PunktTokenizer(language)
#     106
#     107
#
# /usr/local/lib/python3.10/dist-packages/nltk/tokenize/punkt.py in __init__(self, lang)
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
import nltk
import os

nltk.data.path.append(os.path.expanduser('~') + '/nltk_data')
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# True

# %%
import nltk

# Force download the 'punkt' tokenizer
nltk.download('punkt', force=True)

# Verify the download directory
nltk.data.path.append('/usr/local/nltk_data')
print("Download complete and path set.")
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# Download complete and path set.

# %%
import nltk

# Download the 'punkt_tab' resource
nltk.download('punkt_tab')

# Your code for sentence and word tokenization:
sen = nltk.sent_tokenize(data_text)
print("Tokenized Sentences:", sen)

words = nltk.word_tokenize(data_text)
print("Tokenized Words:", words)
# Out:
# [nltk_data] Downloading package punkt_tab to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt_tab.zip.
# ...

# %%
data_text
# Out:
# ' data science is an interdisciplinary academic field that uses statistics, scientific computing, scientific methods, processing, scientific visualization, algorithms and systems to extract or extrapolate knowledge and insights from potentially noisy, structured, or unstructured data. data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine). data science is multifaceted and can be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession. data science is "a concept to unify statistics, data analysis, informatics, and their related methods" to "understand and analyze actual phenomena" with data. it uses techniques and theories drawn from many fields within the context of mathematics, statistics, computer science, information science, and domain knowledge. however, data science is different from computer science and information science. turing awar
# ...

# %%
sen
# Out:
# [' data science is an interdisciplinary academic field that uses statistics, scientific computing, scientific methods, processing, scientific visualization, algorithms and systems to extract or extrapolate knowledge and insights from potentially noisy, structured, or unstructured data.',
#  'data science also integrates domain knowledge from the underlying application domain (e.g., natural sciences, information technology, and medicine).',
#  'data science is multifaceted and can be described as a science, a research paradigm, a research method, a discipline, a workflow, and a profession.',
#  'data science is "a concept to unify statistics, data analysis, informatics, and their related methods" to "understand and analyze actual phenomena" with data.',
#  'it uses techniques and theories drawn from many fields within the context of mathematics, statistics, computer science, information science, and domain knowledge.',
# ...

# %%
words
# Out:
# ['data',
#  'science',
#  'is',
#  'an',
#  'interdisciplinary',
#  'academic',
#  'field',
#  'that',
#  'uses',
#  'statistics',
#  ',',
#  'scientific',
#  'computing',
#  ',',
#  'scientific',
#  'methods',
#  ',',
#  'processing',
#  ',',
#  'scientific',
#  'visualization',
#  ',',
#  'algorithms',
#  'and',
#  'systems',
#  'to',
#  'extract',
#  'or',
#  'extrapolate',
#  'knowledge',
#  'and',
#  'insights',
#  'from',
#  'potentially',
#  'noisy',
#  ',',
#  'structured',
#  ',',
#  'or',
#  'unstructured',
#  'data',
#  '.',
#  'data',
#  'science',
#  'also',
#  'integrates',
#  'domain',
#  'knowledge',
#  'from',
#  'the',
#  'underlying',
#  'application',
#  'domain',
#  '(',
#  'e.g.',
#  ',',
#  'natural',
#  'sciences',
#  ',',
#  'information',
#  'technology',
#  ',',
#  'and',
#  'medicine',
#  ')',
#  '.',
#  'data',
#  'science',
#  'is',
#  'multifaceted',
#  'and',
#  'can',
#  'be',
#  'described',
#  'as',
#  'a',
#  'science',
#  ',',
#  'a',
# ...

# %%
#lemitization
lemma =nltk.stem.WordNetLemmatizer()

# %%
def perform_lemmatization(tokens):
    return [lemma.lemmatize(word) for word in tokens]

# %%
# remove punctuation
pr =dict((ord(punct),None) for punct in string.punctuation)

# %%
def get_processed_text(document):
    return perform_lemmatization(nltk.word_tokenize(document.lower().translate(pr)))

# %%
greeting_inputs = ("hey", "good morning", "good evening", "morning", "evening", "hi", "whatsup")
greeting_responses = ["hey", "hey hows you?", "*nods*", "hello, how you doing", "hello", "Welcome, I am good and you"]
def generate_greeting_response(greeting):
    for token in greeting.split():
        if token.lower() in greeting_inputs:
            return random.choice(greeting_responses)

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity

# %%
# make and genrate a response function
def generate_response(user_input):
    bot_response = ''
    sen.append(user_input)

    word_vectorizer = TfidfVectorizer(tokenizer=get_processed_text, stop_words='english')
    word_vectors = word_vectorizer.fit_transform(sen)
    similar_vector_values = cosine_similarity(word_vectors[-1], all_word_vectors)
    similar_sentence_number = similar_vector_values.argsort()[0][-2]

    matched_vector = similar_vector_values.flatten()
    matched_vector.sort()
    vector_matched = matched_vector[-2]

    if vector_matched == 0:
        bot_response = bot_response + "I am sorry, I could not understand you"
        return bot_response
    else:
        bot_response = bot_response + sen[similar_sentence_number]
        return bot_response

# %%
import nltk

# Download the 'wordnet' dataset
nltk.download('wordnet')

import numpy as np
import random
import string

import bs4 as bs
import urllib.request
import re

# ... (rest of your code) ...
# Out:
# [nltk_data] Downloading package wordnet to /root/nltk_data...

# %%
#######

continue_flag = True
print("Hello, I am the learning bot. I will try to learn about data science. If you want to exit, type Bye!")
while(continue_flag == True):
    human = input()
    human = human.lower()
    if human != 'bye':
        if human == 'thanks' or human == 'thank you very much' or human == 'thank you' :
          continue_flag =False
          print("You are welcome..")
        else:
            if generate_greeting_response(human) != None:
                print("Bot Response: " + generate_greeting_response(human))
            else:
              print("Bot Response",end="")
              print(generate_response(human))
              sen.remove(human)
    else:
        continue_flag = False
        print("Bye take care..")
# Out:
# Hello, I am the learning bot. I will try to learn about data science. If you want to exit, type Bye!
# by
# Bot ResponseI am sorry, I could not understand you
# bye
# Bye take care..

# %%
def generate_response(user_input):
    bot_response = ''
    sen.append(user_input)

    word_vectorizer = TfidfVectorizer(tokenizer=get_processed_text, stop_words='english')
    word_vectors = word_vectorizer.fit_transform(sen)

    # Calculate cosine similarity with all word vectors
    # instead of the undefined 'all_word_vectors'
    all_word_vectors = word_vectors[:-1]  # All vectors except the last one (user input)
    similar_vector_values = cosine_similarity(word_vectors[-1], all_word_vectors)

    similar_sentence_number = similar_vector_values.argsort()[0][-2]

    matched_vector = similar_vector_values.flatten()
    matched_vector.sort()
    vector_matched = matched_vector[-2]

    if vector_matched == 0:
        bot_response = bot_response + "I am sorry, I could not understand you"
        return bot_response
    else:
        bot_response = bot_response + sen[similar_sentence_number]
        return bot_response

# %%
continue_flag = True
print("Hello, I am the learning bot. shoot your question")
while(continue_flag == True):
    human = input()
    human = human.lower()
    if human != 'bye':
        if human == 'thanks' or human == 'thank you very much' or human == 'thank you' :
          continue_flag =False
          print("You are welcome..")
        else:
            if generate_greeting_response(human) != None:
                print("Bot Response: " + generate_greeting_response(human))
            else:
              print("Bot Response",end="")
              print(generate_response(human))
              sen.remove(human)
    else:
        continue_flag = False
        print(" Bye take care..")
# Out:
# Hello, I am the learning bot. shoot your question
# Bot Response"data science" became more widely used in the next few years: in 2002, the committee on data for science and technology launched the data science journal.
# by
# Bot ResponseI am sorry, I could not understand you
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-32-6a6fef1028b4> in <cell line: 3>()
#       2 print("Hello, I am the learning bot. shoot your question")
#       3 while(continue_flag == True):
# ----> 4     human = input()
#       5     human = human.lower()
#       6     if human != 'bye':
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
# ...
